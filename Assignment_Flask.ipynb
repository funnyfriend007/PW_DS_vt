# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
## Q1. What is Flask Framework? 

'''What is Flask Framework? ---------------------------------------------------------------
Flask is a web framework, it’s a Python module that lets you develop web applications easily.
It’s has a small and easy-to-extend core: it’s a microframework that 
doesn’t include an ORM (Object Relational Manager) or such features.
It does have many cool features like url routing, template engine. It is a WSGI web app framework.
'''

###What are the advantages of Flask Framework
'''
What are the advantages of Flask Framework ------------------------------------------------
It is a lightweight framework that offers hassle-free development
Provide flexibility to the developer to experiment with their modules or architecture
It is suitable for small projects
Offers a built-in development server and fast debugger
Easily scalable for the applications
Support for secure cookies
Uses Ninja2 Template engine
It has integrated support for unit testing
APIs are coherent and neat
Provide strong WSGI support

'''

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook

# %%
from flask import Flask
obj_var = Flask(__name__)   ##creates the Flask instance. Class name is Flask , app is just a object variable
@obj_var.route("/")   ## this / is for home location so first will execute when we run URL
def func1():
    return "Hello World!!"

if __name__=="__main__":
    obj_var.run(host="0.0.0.0")

## I have attched screeshot of output in below cell

# %% [markdown]
# ![image.png](attachment:634aa7a6-fa68-4cd1-947a-94d505e02daa.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %%
###What is App Routing in Flask?Why do we use app routes?
'''
App routing is the technique used to map the specific URL with the associated function 
intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs.
This is done so that code is not LANGUAGE/PLATFORM independent , rather URL dependent which uses http only.
 
There are two ways through which we can bind the URLs:-
a.) Using route() decorator
b.) Using add_url_rule() function
 
‘/’ URL is the root URL for any application.
'''

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# ### Contact Detail: 999-999-9999

# %%
from flask import Flask
obj_var = Flask(__name__)   ##creates the Flask instance. Class name is Flask , app is just a object variable
prnt_var="Company Name: ABC Corporation \
         Location: India \
         Contact Detail: 999-999-9999"

@obj_var.route("/")   ## this / is for home location so first will execute when we run URL
def func():
    return prnt_var

@obj_var.route("/welcome")   
def func1():
    return "Welcome to ABC Corporation"

if __name__=="__main__":
    obj_var.run(host="0.0.0.0")
    
### images are attched in below 2 cells
# Out:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![image.png](attachment:5cf53cb7-31fc-47b5-a26b-a40d153297c2.png)

# %% [markdown]
# ![image.png](attachment:94698302-d4df-4a8e-b408-4717bc1b87b5.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
###What function is used in Flask for URL Building?
'''
The url_for() function is used to build a URL to the specific function dynamically. 
The first argument is the name of the specified function, and then we can pass any number of keyword argument 
corresponding to the variable part of the URL.
This function is useful in the sense that we can avoid hard-coding the URLs into the 
templates by dynamically building them using this function.
'''

## here https://lemon-dentist-pvlxm.pwskills.app:5000/user/admin will redirect to https://lemon-dentist-pvlxm.pwskills.app:/admin
## here https://lemon-dentist-pvlxm.pwskills.app:5000/user/student will redirect to https://lemon-dentist-pvlxm.pwskills.app:/student
from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'   
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'student':  
        return redirect(url_for('student'))  

if __name__=="__main__":
    app.run(host="0.0.0.0")
